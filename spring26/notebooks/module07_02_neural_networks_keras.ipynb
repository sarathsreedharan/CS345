# %% [markdown]
# *This notebook is part of  course materials for CS 345: Machine Learning Foundations and Practice at Colorado State University.
# Original versions were created by Ben Sattelberg and Asa Ben-Hur.
# The content is availabe [on GitHub](https://github.com/asabenhur/CS345).*
#
# *The text is released under the [CC BY-SA license](https://creativecommons.org/licenses/by-sa/4.0/), and code is released under the [MIT license](https://opensource.org/licenses/MIT).*

# %% [markdown]
# <a href="https://colab.research.google.com/github//asabenhur/CS345/blob/master/fall22/notebooks/module07_02_neural_networks_keras.ipynb">
#   <img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Neural Networks with Keras

# %%
import numpy as np
#import keras
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib
tf.executing_eagerly()
# Out:
# True

# %% [markdown]
# ### Plotting functionality for later

# %%
from mpl_toolkits.mplot3d import Axes3D

def plot_XOR_network(network, two_outputs=False, transform=None):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    #ax2 = fig.add_subplot(122, projection='3d')

    delta = 0.01
    xmin=-0.1;xmax=1.1;ymin=-0.1;ymax=1.1
    xs = np.arange(xmin, xmax, delta)
    ys = np.arange(ymin, ymax, delta)
    x_grid, y_grid = np.meshgrid(xs, ys)

    xs = x_grid.reshape(-1)
    ys = y_grid.reshape(-1)
    x = np.vstack((xs, ys))
    Z = network.predict(x.T)
    if two_outputs and not transform:
        Z = Z[:, 1] - Z[:, 0]
    elif two_outputs and transform:
        Z = transform(Z[:, 1]) - transform(Z[:, 0])
    Z = Z.reshape(x_grid.shape)

    if two_outputs:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=-1, vmax=1)
    else:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=0, vmax=1)

    X = np.array([[0, 0], [1, 0], [0, 1], [1, 1]])
    y = np.array([1, 0, 0, 1])

    plt.style.use('default')
    ax.scatter(X[:,0], X[:,1], c=y, s=50, cmap='bwr', edgecolors='w');
    ax.plot([], [], 'or', label='1')
    ax.plot([], [], 'ob', label='0')
    ax.set_xlabel('$x_1$')
    ax.set_ylabel('$x_2$')
    ax.legend()

#     ax2.plot_wireframe(x_grid, y_grid, Z, alpha=0.5);
#     ax2.scatter(X[:,0], X[:,1], y, c=y, alpha=1, s=20, cmap='bwr')

#     ax2.set_xlabel('$x_1$')
#     ax2.set_ylabel('$x_2$')
#     ax2.set_zlabel('f($x_1$, $x_2$)');

# %%
def plot_circles_network(network, two_outputs=False, transform=None):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    #ax2 = fig.add_subplot(122, projection='3d')
    
    r1 = 0.5
    r2 = np.sqrt(2*r1**2)
    r3 = np.sqrt(r1**2 + r2**2)

    delta = 0.01
    xmin=-1.1;xmax=1.1;ymin=-1.1;ymax=1.1
    xs = np.arange(xmin, xmax, delta)
    ys = np.arange(ymin, ymax, delta)
    x_grid, y_grid = np.meshgrid(xs, ys)

    xs = x_grid.reshape(-1)
    ys = y_grid.reshape(-1)
    x = np.vstack((xs, ys))
    Z = network.predict(x.T)
    if two_outputs and not transform:
        Z = Z[:, 1] - Z[:, 0]
    elif two_outputs and transform:
        Z = transform(Z[:, 1]) - transform(Z[:, 0])
    Z = Z.reshape(x_grid.shape)

    if two_outputs:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=-0.001, vmax=0.001)
    else:
        im = ax.imshow(Z, origin='lower',
                    cmap=plt.cm.bwr, extent=(xmin,xmax,ymin,ymax), vmin=0, vmax=1)

    plt.style.use('default')
    #ax.scatter(X[:,0], X[:,1], c=y, s=50, cmap='bwr', edgecolors='w');
    ax.plot([], [], 'or', label='1')
    ax.plot([], [], 'ob', label='0')
    ax.set_xlabel('$x_1$')
    ax.set_ylabel('$x_2$')
    ax.legend()
    
    circle = plt.Circle((0, 0), r1, alpha=0.5, edgecolor='k')
    annulus = matplotlib.patches.Wedge((0, 0), r3, 0, 360, width=r3-r2, facecolor='r', alpha=0.5, edgecolor='k')
    ax.add_artist(circle)
    ax.add_artist(annulus)

#     ax2.plot_wireframe(x_grid, y_grid, Z, alpha=0.5);

#     ax2.set_xlabel('$x_1$')
#     ax2.set_ylabel('$x_2$')
#     ax2.set_zlabel('f($x_1$, $x_2$)');

# %% [markdown]
# ## Introduction to Keras

# %% [markdown]
# Last time we introduced neural networks and built a simple architecture we could use to (sometimes) solve the XOR problem.  We saw the challenge of programming a network with increasing numbers of units and layers.
#
# Fortunately, there exist a number of packages designed for neural networks use that automatically determine the correct update rules with backpropagation.  A few of the packages that are used in CSU's CS department are [TensorFlow](https://www.tensorflow.org), [PyTorch](https://pytorch.org), and [Keras](https://keras.io).  These packages use Python despite the fact that Python may be relatively slow compared to compiled languages.  These deep learning packages often compile their code into those faster languages or are able to take advantage of optimizations that give competitive performance.
#
# We'll use Keras with a TensorFlow backend as it is simple to use and competitive with other options.

# %% [markdown]
# The [Keras website](https://keras.io/) has good tutorials and documentation.

# %% [markdown]
# First, we will create our dataset - the same XOR problem discussed in the previous notebook.  The only difference is that we convert the input values to be 32 bit floating point values, rather than 64 bit.  This isn't strictly necessary, but most neural network packages use 32 bit floats because the added precision is not worth the memory and computational cost.

# %%
X_xor = np.array([[0, 0], [1, 0], [0, 1], [1, 1]])
y_xor = np.array([1, 0, 0, 1])

X_xor = X_xor.astype('float32')

# %% [markdown]
# Now we can set up a network.  We will use a ```Sequential``` network, which is the container for the multilayer perceptron/feedforward neural network structure we have been using so far.

# %%
network1 = tf.keras.Sequential()

# %% [markdown]
# Now we can add layers to it.  The first layer we add is our hidden layer.  Having two nodes would give us a network which *can* work, but frequently doesn't, so let's create a much larger network with ten nodes in its hidden layer.  This is referred to as a ```Dense``` layer, as every input has a weight connecting it to every node in the previous layer.  We also tell Keras to use the ReLU activation function for it.
#
# Finally, we will add a layer that transforms the outputs of the hidden layer into the single output value.  By not passing an activation function in, this defaults to having no activation function.

# %%
network1.add(tf.keras.layers.Dense(10, activation='relu', input_shape=(2,)))
network1.add(tf.keras.layers.Dense(1))

# %% [markdown]
# This sets up a network that looks like this:

# %% [markdown]
# <img style="padding:10px;width:80%;" alt="Simple multilayer perceptron architecture" src="https://github.com/asabenhur/CS345/raw/master/fall20/notebooks/figures/single_hidden_10_node.png">

# %% [markdown]
# Given the network, we can now set up the training process.  We will use the mean squared error as the loss function and use stochastic gradient descent as the optimizer:

# %%
#loss_fn = tf.keras.losses.MeanSquaredError()

opt = tf.keras.optimizers.SGD(learning_rate=0.005)

# %% [markdown]
# The command ```network.compile(...)``` constructs the network as something that can be trained or evaluated.  The ```metrics``` parameter accepts a list of values that we want to keep track of during the training process.

# %%
network1.compile(loss='mse', optimizer=opt, metrics=['accuracy', 'mse'])

# %% [markdown]
# With all of the set up out of the way, we are ready to train the network.  The ```batch_size``` controls how many inputs to pass through the network at a time.   With traditional gradient descent it would be every input and with traditional stochastic gradient descent it would be a single input.  The ```verbose``` parameter controls to what extent the network prints output reflecting its progress.  Notice that it keeps track of the loss used for training, and the 'accuracy' and 'mse' values that we passed as metrics of interest.  In this case the loss is MSE, so the two values are the same.

# %%
history1 = network1.fit(X_xor, y_xor, batch_size=2, epochs=500, verbose=1)
# Out:
# Epoch 1/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.6316 - accuracy: 0.5000 - mse: 0.6316
# Epoch 2/500
# 2/2 [==============================] - 0s 725us/step - loss: 0.5978 - accuracy: 0.5000 - mse: 0.5978
# Epoch 3/500
# 2/2 [==============================] - 0s 907us/step - loss: 0.5702 - accuracy: 0.5000 - mse: 0.5702
# Epoch 4/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.5402 - accuracy: 0.5000 - mse: 0.5402
# Epoch 5/500
# 2/2 [==============================] - 0s 797us/step - loss: 0.5119 - accuracy: 0.5000 - mse: 0.5119
# Epoch 6/500
# 2/2 [==============================] - 0s 754us/step - loss: 0.4908 - accuracy: 0.5000 - mse: 0.4908
# Epoch 7/500
# 2/2 [==============================] - 0s 886us/step - loss: 0.4800 - accuracy: 0.2500 - mse: 0.4800
# Epoch 8/500
# 2/2 [==============================] - 0s 627us/step - loss: 0.4636 - accuracy: 0.2500 - mse: 0.4636
# Epoch 9/500
# 2/2 [==============================] - 0s 774us/step - loss: 0.4490 - accuracy: 0.2500 - mse: 0.4490
# Epoch 10/500
# 2/2 [==============================] - 0s 878us/step - loss: 0.4313 - accuracy: 0.2500 - mse: 0.4313
# Epoch 11/500
# 2/2 [==============================] - 0s 692us/step - loss: 0.4162 - accuracy: 0.2500 - mse: 0.4162
# Epoch 12/500
# 2/2 [==============================] - 0s 858us/step - loss: 0.4083 - accuracy: 0.2500 - mse: 0.4083
# Epoch 13/500
# 2/2 [==============================] - 0s 836us/step - loss: 0.3957 - accuracy: 0.2500 - mse: 0.3957
# Epoch 14/500
# 2/2 [==============================] - 0s 634us/step - loss: 0.3943 - accuracy: 0.2500 - mse: 0.3943
# Epoch 15/500
# 2/2 [==============================] - 0s 645us/step - loss: 0.3864 - accuracy: 0.2500 - mse: 0.3864
# Epoch 16/500
# 2/2 [==============================] - 0s 939us/step - loss: 0.3720 - accuracy: 0.2500 - mse: 0.3720
# Epoch 17/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.3655 - accuracy: 0.2500 - mse: 0.3655
# Epoch 18/500
# 2/2 [==============================] - 0s 640us/step - loss: 0.3668 - accuracy: 0.2500 - mse: 0.3668
# Epoch 19/500
# 2/2 [==============================] - 0s 753us/step - loss: 0.3542 - accuracy: 0.2500 - mse: 0.3542
# Epoch 20/500
# 2/2 [==============================] - 0s 934us/step - loss: 0.3561 - accuracy: 0.2500 - mse: 0.3561
# Epoch 21/500
# 2/2 [==============================] - 0s 720us/step - loss: 0.3443 - accuracy: 0.2500 - mse: 0.3443
# Epoch 22/500
# 2/2 [==============================] - 0s 710us/step - loss: 0.3417 - accuracy: 0.2500 - mse: 0.3417
# Epoch 23/500
# 2/2 [==============================] - 0s 713us/step - loss: 0.3429 - accuracy: 0.2500 - mse: 0.3429
# Epoch 24/500
# 2/2 [==============================] - 0s 673us/step - loss: 0.3392 - accuracy: 0.2500 - mse: 0.3392
# Epoch 25/500
# 2/2 [==============================] - 0s 750us/step - loss: 0.3356 - accuracy: 0.2500 - mse: 0.3356
# Epoch 26/500
# 2/2 [==============================] - 0s 703us/step - loss: 0.3322 - accuracy: 0.2500 - mse: 0.3322
# Epoch 27/500
# 2/2 [==============================] - 0s 635us/step - loss: 0.3222 - accuracy: 0.2500 - mse: 0.3222
# Epoch 28/500
# 2/2 [==============================] - 0s 627us/step - loss: 0.3205 - accuracy: 0.2500 - mse: 0.3205
# Epoch 29/500
# 2/2 [==============================] - 0s 692us/step - loss: 0.3162 - accuracy: 0.2500 - mse: 0.3162
# Epoch 30/500
# 2/2 [==============================] - 0s 763us/step - loss: 0.3148 - accuracy: 0.5000 - mse: 0.3148
# Epoch 31/500
# 2/2 [==============================] - 0s 729us/step - loss: 0.3109 - accuracy: 0.5000 - mse: 0.3109
# Epoch 32/500
# 2/2 [==============================] - 0s 646us/step - loss: 0.3149 - accuracy: 0.2500 - mse: 0.3149
# Epoch 33/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.3059 - accuracy: 0.5000 - mse: 0.3059
# Epoch 34/500
# 2/2 [==============================] - 0s 679us/step - loss: 0.3048 - accuracy: 0.5000 - mse: 0.3048
# Epoch 35/500
# 2/2 [==============================] - 0s 583us/step - loss: 0.3013 - accuracy: 0.5000 - mse: 0.3013
# Epoch 36/500
# 2/2 [==============================] - 0s 820us/step - loss: 0.2992 - accuracy: 0.5000 - mse: 0.2992
# Epoch 37/500
# 2/2 [==============================] - 0s 794us/step - loss: 0.3034 - accuracy: 0.5000 - mse: 0.3034
# Epoch 38/500
# 2/2 [==============================] - 0s 824us/step - loss: 0.2961 - accuracy: 0.5000 - mse: 0.2961
# Epoch 39/500
# 2/2 [==============================] - 0s 902us/step - loss: 0.2993 - accuracy: 0.5000 - mse: 0.2993
# Epoch 40/500
# 2/2 [==============================] - 0s 755us/step - loss: 0.2927 - accuracy: 0.5000 - mse: 0.2927
# Epoch 41/500
# 2/2 [==============================] - 0s 652us/step - loss: 0.2896 - accuracy: 0.5000 - mse: 0.2896
# Epoch 42/500
# 2/2 [==============================] - 0s 599us/step - loss: 0.2941 - accuracy: 0.5000 - mse: 0.2941
# Epoch 43/500
# 2/2 [==============================] - 0s 851us/step - loss: 0.2867 - accuracy: 0.5000 - mse: 0.2867
# Epoch 44/500
# 2/2 [==============================] - 0s 722us/step - loss: 0.2848 - accuracy: 0.5000 - mse: 0.2848
# Epoch 45/500
# 2/2 [==============================] - 0s 697us/step - loss: 0.2844 - accuracy: 0.5000 - mse: 0.2844
# Epoch 46/500
# 2/2 [==============================] - 0s 584us/step - loss: 0.2830 - accuracy: 0.5000 - mse: 0.2830
# Epoch 47/500
# 2/2 [==============================] - 0s 843us/step - loss: 0.2864 - accuracy: 0.5000 - mse: 0.2864
# Epoch 48/500
# 2/2 [==============================] - 0s 647us/step - loss: 0.2801 - accuracy: 0.5000 - mse: 0.2801
# Epoch 49/500
# 2/2 [==============================] - 0s 825us/step - loss: 0.2785 - accuracy: 0.5000 - mse: 0.2785
# Epoch 50/500
# 2/2 [==============================] - 0s 571us/step - loss: 0.2757 - accuracy: 0.5000 - mse: 0.2757
# Epoch 51/500
# 2/2 [==============================] - 0s 583us/step - loss: 0.2807 - accuracy: 0.5000 - mse: 0.2807
# Epoch 52/500
# 2/2 [==============================] - 0s 578us/step - loss: 0.2741 - accuracy: 0.5000 - mse: 0.2741
# Epoch 53/500
# 2/2 [==============================] - 0s 683us/step - loss: 0.2727 - accuracy: 0.5000 - mse: 0.2727
# Epoch 54/500
# 2/2 [==============================] - 0s 716us/step - loss: 0.2714 - accuracy: 0.5000 - mse: 0.2714
# Epoch 55/500
# 2/2 [==============================] - 0s 948us/step - loss: 0.2699 - accuracy: 0.5000 - mse: 0.2699
# Epoch 56/500
# 2/2 [==============================] - 0s 730us/step - loss: 0.2678 - accuracy: 0.5000 - mse: 0.2678
# Epoch 57/500
# 2/2 [==============================] - 0s 771us/step - loss: 0.2672 - accuracy: 0.5000 - mse: 0.2672
# Epoch 58/500
# 2/2 [==============================] - 0s 758us/step - loss: 0.2658 - accuracy: 0.5000 - mse: 0.2658
# Epoch 59/500
# 2/2 [==============================] - 0s 856us/step - loss: 0.2647 - accuracy: 0.5000 - mse: 0.2647
# Epoch 60/500
# 2/2 [==============================] - 0s 802us/step - loss: 0.2634 - accuracy: 0.5000 - mse: 0.2634
# Epoch 61/500
# 2/2 [==============================] - 0s 758us/step - loss: 0.2614 - accuracy: 0.5000 - mse: 0.2614
# Epoch 62/500
# 2/2 [==============================] - 0s 605us/step - loss: 0.2601 - accuracy: 0.5000 - mse: 0.2601
# Epoch 63/500
# 2/2 [==============================] - 0s 754us/step - loss: 0.2598 - accuracy: 0.5000 - mse: 0.2598
# Epoch 64/500
# 2/2 [==============================] - 0s 743us/step - loss: 0.2638 - accuracy: 0.5000 - mse: 0.2638
# Epoch 65/500
# 2/2 [==============================] - 0s 788us/step - loss: 0.2621 - accuracy: 0.5000 - mse: 0.2621
# Epoch 66/500
# 2/2 [==============================] - 0s 607us/step - loss: 0.2552 - accuracy: 0.5000 - mse: 0.2552
# Epoch 67/500
# 2/2 [==============================] - 0s 547us/step - loss: 0.2539 - accuracy: 0.5000 - mse: 0.2539
# Epoch 68/500
# 2/2 [==============================] - 0s 705us/step - loss: 0.2536 - accuracy: 0.5000 - mse: 0.2536
# Epoch 69/500
# 2/2 [==============================] - 0s 664us/step - loss: 0.2521 - accuracy: 0.5000 - mse: 0.2521
# Epoch 70/500
# 2/2 [==============================] - 0s 745us/step - loss: 0.2514 - accuracy: 0.5000 - mse: 0.2514
# Epoch 71/500
# 2/2 [==============================] - 0s 772us/step - loss: 0.2503 - accuracy: 0.5000 - mse: 0.2503
# Epoch 72/500
# 2/2 [==============================] - 0s 732us/step - loss: 0.2488 - accuracy: 0.5000 - mse: 0.2488
# Epoch 73/500
# 2/2 [==============================] - 0s 751us/step - loss: 0.2473 - accuracy: 0.5000 - mse: 0.2473
# Epoch 74/500
# 2/2 [==============================] - 0s 728us/step - loss: 0.2469 - accuracy: 0.5000 - mse: 0.2469
# Epoch 75/500
# 2/2 [==============================] - 0s 651us/step - loss: 0.2458 - accuracy: 0.5000 - mse: 0.2458
# Epoch 76/500
# 2/2 [==============================] - 0s 858us/step - loss: 0.2438 - accuracy: 0.5000 - mse: 0.2438
# Epoch 77/500
# 2/2 [==============================] - 0s 667us/step - loss: 0.2486 - accuracy: 0.5000 - mse: 0.2486
# Epoch 78/500
# 2/2 [==============================] - 0s 844us/step - loss: 0.2426 - accuracy: 0.5000 - mse: 0.2426
# Epoch 79/500
# 2/2 [==============================] - 0s 561us/step - loss: 0.2463 - accuracy: 0.5000 - mse: 0.2463
# Epoch 80/500
# 2/2 [==============================] - 0s 564us/step - loss: 0.2448 - accuracy: 0.5000 - mse: 0.2448
# Epoch 81/500
# 2/2 [==============================] - 0s 618us/step - loss: 0.2440 - accuracy: 0.5000 - mse: 0.2440
# Epoch 82/500
# 2/2 [==============================] - 0s 517us/step - loss: 0.2382 - accuracy: 0.5000 - mse: 0.2382
# Epoch 83/500
# 2/2 [==============================] - 0s 662us/step - loss: 0.2423 - accuracy: 0.5000 - mse: 0.2423
# Epoch 84/500
# 2/2 [==============================] - 0s 592us/step - loss: 0.2351 - accuracy: 0.5000 - mse: 0.2351
# Epoch 85/500
# 2/2 [==============================] - 0s 613us/step - loss: 0.2352 - accuracy: 0.5000 - mse: 0.2352
# Epoch 86/500
# 2/2 [==============================] - 0s 521us/step - loss: 0.2383 - accuracy: 0.5000 - mse: 0.2383
# Epoch 87/500
# 2/2 [==============================] - 0s 753us/step - loss: 0.2324 - accuracy: 0.5000 - mse: 0.2324
# Epoch 88/500
# 2/2 [==============================] - 0s 658us/step - loss: 0.2317 - accuracy: 0.5000 - mse: 0.2317
# Epoch 89/500
# 2/2 [==============================] - 0s 629us/step - loss: 0.2305 - accuracy: 0.5000 - mse: 0.2305
# Epoch 90/500
# 2/2 [==============================] - 0s 586us/step - loss: 0.2293 - accuracy: 0.5000 - mse: 0.2293
# Epoch 91/500
# 2/2 [==============================] - 0s 557us/step - loss: 0.2338 - accuracy: 0.5000 - mse: 0.2338
# Epoch 92/500
# 2/2 [==============================] - 0s 588us/step - loss: 0.2274 - accuracy: 0.5000 - mse: 0.2274
# Epoch 93/500
# 2/2 [==============================] - 0s 787us/step - loss: 0.2262 - accuracy: 0.5000 - mse: 0.2262
# Epoch 94/500
# 2/2 [==============================] - 0s 719us/step - loss: 0.2254 - accuracy: 0.5000 - mse: 0.2254
# Epoch 95/500
# 2/2 [==============================] - 0s 840us/step - loss: 0.2243 - accuracy: 0.5000 - mse: 0.2243
# Epoch 96/500
# 2/2 [==============================] - 0s 852us/step - loss: 0.2235 - accuracy: 0.5000 - mse: 0.2235
# Epoch 97/500
# 2/2 [==============================] - 0s 689us/step - loss: 0.2225 - accuracy: 0.5000 - mse: 0.2225
# Epoch 98/500
# 2/2 [==============================] - 0s 695us/step - loss: 0.2224 - accuracy: 0.5000 - mse: 0.2224
# Epoch 99/500
# 2/2 [==============================] - 0s 719us/step - loss: 0.2260 - accuracy: 0.5000 - mse: 0.2260
# Epoch 100/500
# 2/2 [==============================] - 0s 614us/step - loss: 0.2206 - accuracy: 0.5000 - mse: 0.2206
# Epoch 101/500
# 2/2 [==============================] - 0s 814us/step - loss: 0.2188 - accuracy: 0.5000 - mse: 0.2188
# Epoch 102/500
# 2/2 [==============================] - 0s 689us/step - loss: 0.2177 - accuracy: 0.5000 - mse: 0.2177
# Epoch 103/500
# 2/2 [==============================] - 0s 739us/step - loss: 0.2170 - accuracy: 0.5000 - mse: 0.2170
# Epoch 104/500
# 2/2 [==============================] - 0s 672us/step - loss: 0.2212 - accuracy: 0.5000 - mse: 0.2212
# Epoch 105/500
# 2/2 [==============================] - 0s 766us/step - loss: 0.2152 - accuracy: 0.5000 - mse: 0.2152
# Epoch 106/500
# 2/2 [==============================] - 0s 682us/step - loss: 0.2189 - accuracy: 0.5000 - mse: 0.2189
# Epoch 107/500
# 2/2 [==============================] - 0s 862us/step - loss: 0.2183 - accuracy: 0.5000 - mse: 0.2183
# Epoch 108/500
# 2/2 [==============================] - 0s 749us/step - loss: 0.2177 - accuracy: 0.5000 - mse: 0.2177
# Epoch 109/500
# 2/2 [==============================] - 0s 747us/step - loss: 0.2115 - accuracy: 0.5000 - mse: 0.2115
# Epoch 110/500
# 2/2 [==============================] - 0s 941us/step - loss: 0.2115 - accuracy: 0.5000 - mse: 0.2115
# Epoch 111/500
# 2/2 [==============================] - 0s 783us/step - loss: 0.2104 - accuracy: 0.5000 - mse: 0.2104
# Epoch 112/500
# 2/2 [==============================] - 0s 800us/step - loss: 0.2141 - accuracy: 0.7500 - mse: 0.2141
# Epoch 113/500
# 2/2 [==============================] - 0s 705us/step - loss: 0.2087 - accuracy: 0.5000 - mse: 0.2087
# Epoch 114/500
# 2/2 [==============================] - 0s 549us/step - loss: 0.2072 - accuracy: 0.7500 - mse: 0.2072
# Epoch 115/500
# 2/2 [==============================] - 0s 618us/step - loss: 0.2113 - accuracy: 0.7500 - mse: 0.2113
# Epoch 116/500
# 2/2 [==============================] - 0s 589us/step - loss: 0.2101 - accuracy: 0.7500 - mse: 0.2101
# Epoch 117/500
# 2/2 [==============================] - 0s 806us/step - loss: 0.2093 - accuracy: 0.5000 - mse: 0.2093
# Epoch 118/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2036 - accuracy: 0.7500 - mse: 0.2036
# Epoch 119/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2028 - accuracy: 0.7500 - mse: 0.2028
# Epoch 120/500
# 2/2 [==============================] - 0s 857us/step - loss: 0.2026 - accuracy: 0.7500 - mse: 0.2026
# Epoch 121/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.2063 - accuracy: 0.7500 - mse: 0.2063
# Epoch 122/500
# 2/2 [==============================] - 0s 973us/step - loss: 0.2009 - accuracy: 0.7500 - mse: 0.2009
# Epoch 123/500
# 2/2 [==============================] - 0s 891us/step - loss: 0.2043 - accuracy: 0.7500 - mse: 0.2043
# Epoch 124/500
# 2/2 [==============================] - 0s 650us/step - loss: 0.2034 - accuracy: 0.7500 - mse: 0.2034
# Epoch 125/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1977 - accuracy: 0.7500 - mse: 0.1977
# Epoch 126/500
# 2/2 [==============================] - 0s 893us/step - loss: 0.1976 - accuracy: 0.7500 - mse: 0.1976
# Epoch 127/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1968 - accuracy: 0.7500 - mse: 0.1968
# Epoch 128/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1955 - accuracy: 0.7500 - mse: 0.1955
# Epoch 129/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1946 - accuracy: 0.7500 - mse: 0.1946
# Epoch 130/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1936 - accuracy: 0.7500 - mse: 0.1936
# Epoch 131/500
# 2/2 [==============================] - 0s 815us/step - loss: 0.1936 - accuracy: 0.7500 - mse: 0.1936
# Epoch 132/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1920 - accuracy: 0.7500 - mse: 0.1920
# Epoch 133/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1915 - accuracy: 0.7500 - mse: 0.1915
# Epoch 134/500
# 2/2 [==============================] - 0s 962us/step - loss: 0.1906 - accuracy: 0.7500 - mse: 0.1906
# Epoch 135/500
# 2/2 [==============================] - 0s 949us/step - loss: 0.1897 - accuracy: 0.7500 - mse: 0.1897
# Epoch 136/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1935 - accuracy: 0.7500 - mse: 0.1935
# Epoch 137/500
# 2/2 [==============================] - 0s 992us/step - loss: 0.1888 - accuracy: 0.7500 - mse: 0.1888
# Epoch 138/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1880 - accuracy: 0.7500 - mse: 0.1880
# Epoch 139/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1910 - accuracy: 0.7500 - mse: 0.1910
# Epoch 140/500
# 2/2 [==============================] - 0s 952us/step - loss: 0.1904 - accuracy: 0.7500 - mse: 0.1904
# Epoch 141/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1896 - accuracy: 0.7500 - mse: 0.1896
# Epoch 142/500
# 2/2 [==============================] - 0s 668us/step - loss: 0.1842 - accuracy: 0.7500 - mse: 0.1842
# Epoch 143/500
# 2/2 [==============================] - 0s 601us/step - loss: 0.1838 - accuracy: 0.7500 - mse: 0.1838
# Epoch 144/500
# 2/2 [==============================] - 0s 798us/step - loss: 0.1834 - accuracy: 0.7500 - mse: 0.1834
# Epoch 145/500
# 2/2 [==============================] - 0s 961us/step - loss: 0.1863 - accuracy: 0.7500 - mse: 0.1863
# Epoch 146/500
# 2/2 [==============================] - 0s 726us/step - loss: 0.1820 - accuracy: 0.7500 - mse: 0.1820
# Epoch 147/500
# 2/2 [==============================] - 0s 835us/step - loss: 0.1806 - accuracy: 0.7500 - mse: 0.1806
# Epoch 148/500
# 2/2 [==============================] - 0s 759us/step - loss: 0.1804 - accuracy: 0.7500 - mse: 0.1804
# Epoch 149/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1791 - accuracy: 0.7500 - mse: 0.1791
# Epoch 150/500
# 2/2 [==============================] - 0s 732us/step - loss: 0.1782 - accuracy: 0.7500 - mse: 0.1782
# Epoch 151/500
# 2/2 [==============================] - 0s 832us/step - loss: 0.1777 - accuracy: 0.7500 - mse: 0.1777
# Epoch 152/500
# 2/2 [==============================] - 0s 828us/step - loss: 0.1811 - accuracy: 0.7500 - mse: 0.1811
# Epoch 153/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1801 - accuracy: 0.7500 - mse: 0.1801
# Epoch 154/500
# 2/2 [==============================] - 0s 716us/step - loss: 0.1755 - accuracy: 0.7500 - mse: 0.1755
# Epoch 155/500
# 2/2 [==============================] - 0s 658us/step - loss: 0.1788 - accuracy: 0.7500 - mse: 0.1788
# Epoch 156/500
# 2/2 [==============================] - 0s 677us/step - loss: 0.1746 - accuracy: 0.7500 - mse: 0.1746
# Epoch 157/500
# 2/2 [==============================] - 0s 935us/step - loss: 0.1737 - accuracy: 0.7500 - mse: 0.1737
# Epoch 158/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1730 - accuracy: 0.7500 - mse: 0.1730
# Epoch 159/500
# 2/2 [==============================] - 0s 879us/step - loss: 0.1718 - accuracy: 0.7500 - mse: 0.1718
# Epoch 160/500
# 2/2 [==============================] - 0s 847us/step - loss: 0.1708 - accuracy: 0.7500 - mse: 0.1708
# Epoch 161/500
# 2/2 [==============================] - 0s 758us/step - loss: 0.1709 - accuracy: 0.7500 - mse: 0.1709
# Epoch 162/500
# 2/2 [==============================] - 0s 609us/step - loss: 0.1697 - accuracy: 0.7500 - mse: 0.1697
# Epoch 163/500
# 2/2 [==============================] - 0s 928us/step - loss: 0.1727 - accuracy: 0.7500 - mse: 0.1727
# Epoch 164/500
# 2/2 [==============================] - 0s 726us/step - loss: 0.1690 - accuracy: 0.7500 - mse: 0.1690
# Epoch 165/500
# 2/2 [==============================] - 0s 925us/step - loss: 0.1683 - accuracy: 0.7500 - mse: 0.1683
# Epoch 166/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1673 - accuracy: 0.7500 - mse: 0.1673
# Epoch 167/500
# 2/2 [==============================] - 0s 639us/step - loss: 0.1709 - accuracy: 0.7500 - mse: 0.1709
# Epoch 168/500
# 2/2 [==============================] - 0s 579us/step - loss: 0.1664 - accuracy: 0.7500 - mse: 0.1664
# Epoch 169/500
# 2/2 [==============================] - 0s 833us/step - loss: 0.1664 - accuracy: 0.7500 - mse: 0.1664
# Epoch 170/500
# 2/2 [==============================] - 0s 684us/step - loss: 0.1654 - accuracy: 0.7500 - mse: 0.1654
# Epoch 171/500
# 2/2 [==============================] - 0s 633us/step - loss: 0.1652 - accuracy: 0.7500 - mse: 0.1652
# Epoch 172/500
# 2/2 [==============================] - 0s 926us/step - loss: 0.1643 - accuracy: 0.7500 - mse: 0.1643
# Epoch 173/500
# 2/2 [==============================] - 0s 611us/step - loss: 0.1675 - accuracy: 0.7500 - mse: 0.1675
# Epoch 174/500
# 2/2 [==============================] - 0s 713us/step - loss: 0.1672 - accuracy: 0.7500 - mse: 0.1672
# Epoch 175/500
# 2/2 [==============================] - 0s 586us/step - loss: 0.1626 - accuracy: 0.7500 - mse: 0.1626
# Epoch 176/500
# 2/2 [==============================] - 0s 651us/step - loss: 0.1621 - accuracy: 0.7500 - mse: 0.1621
# Epoch 177/500
# 2/2 [==============================] - 0s 663us/step - loss: 0.1616 - accuracy: 0.7500 - mse: 0.1616
# Epoch 178/500
# 2/2 [==============================] - 0s 563us/step - loss: 0.1609 - accuracy: 0.7500 - mse: 0.1609
# Epoch 179/500
# 2/2 [==============================] - 0s 671us/step - loss: 0.1605 - accuracy: 0.7500 - mse: 0.1605
# Epoch 180/500
# 2/2 [==============================] - 0s 702us/step - loss: 0.1598 - accuracy: 0.7500 - mse: 0.1598
# Epoch 181/500
# 2/2 [==============================] - 0s 857us/step - loss: 0.1600 - accuracy: 0.7500 - mse: 0.1600
# Epoch 182/500
# 2/2 [==============================] - 0s 722us/step - loss: 0.1590 - accuracy: 0.7500 - mse: 0.1590
# Epoch 183/500
# 2/2 [==============================] - 0s 785us/step - loss: 0.1589 - accuracy: 0.7500 - mse: 0.1589
# Epoch 184/500
# 2/2 [==============================] - 0s 554us/step - loss: 0.1583 - accuracy: 0.7500 - mse: 0.1583
# Epoch 185/500
# 2/2 [==============================] - 0s 831us/step - loss: 0.1608 - accuracy: 0.7500 - mse: 0.1608
# Epoch 186/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1571 - accuracy: 0.7500 - mse: 0.1571
# Epoch 187/500
# 2/2 [==============================] - 0s 666us/step - loss: 0.1564 - accuracy: 0.7500 - mse: 0.1564
# Epoch 188/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1596 - accuracy: 0.7500 - mse: 0.1596
# Epoch 189/500
# 2/2 [==============================] - 0s 806us/step - loss: 0.1553 - accuracy: 0.7500 - mse: 0.1553
# Epoch 190/500
# 2/2 [==============================] - 0s 702us/step - loss: 0.1548 - accuracy: 0.7500 - mse: 0.1548
# Epoch 191/500
# 2/2 [==============================] - 0s 920us/step - loss: 0.1579 - accuracy: 0.7500 - mse: 0.1579
# Epoch 192/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1537 - accuracy: 0.7500 - mse: 0.1537
# Epoch 193/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1570 - accuracy: 0.7500 - mse: 0.1570
# Epoch 194/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1564 - accuracy: 0.7500 - mse: 0.1564
# Epoch 195/500
# 2/2 [==============================] - 0s 876us/step - loss: 0.1529 - accuracy: 0.7500 - mse: 0.1529
# Epoch 196/500
# 2/2 [==============================] - 0s 687us/step - loss: 0.1516 - accuracy: 0.7500 - mse: 0.1516
# Epoch 197/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1517 - accuracy: 0.7500 - mse: 0.1517
# Epoch 198/500
# 2/2 [==============================] - 0s 954us/step - loss: 0.1543 - accuracy: 0.7500 - mse: 0.1543
# Epoch 199/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1540 - accuracy: 0.7500 - mse: 0.1540
# Epoch 200/500
# 2/2 [==============================] - 0s 574us/step - loss: 0.1497 - accuracy: 0.7500 - mse: 0.1497
# Epoch 201/500
# 2/2 [==============================] - 0s 761us/step - loss: 0.1528 - accuracy: 0.7500 - mse: 0.1528
# Epoch 202/500
# 2/2 [==============================] - 0s 744us/step - loss: 0.1491 - accuracy: 0.7500 - mse: 0.1491
# Epoch 203/500
# 2/2 [==============================] - 0s 650us/step - loss: 0.1519 - accuracy: 0.7500 - mse: 0.1519
# Epoch 204/500
# 2/2 [==============================] - 0s 666us/step - loss: 0.1478 - accuracy: 0.7500 - mse: 0.1478
# Epoch 205/500
# 2/2 [==============================] - 0s 627us/step - loss: 0.1505 - accuracy: 1.0000 - mse: 0.1505
# Epoch 206/500
# 2/2 [==============================] - 0s 655us/step - loss: 0.1472 - accuracy: 1.0000 - mse: 0.1472
# Epoch 207/500
# 2/2 [==============================] - 0s 595us/step - loss: 0.1462 - accuracy: 1.0000 - mse: 0.1462
# Epoch 208/500
# 2/2 [==============================] - 0s 734us/step - loss: 0.1455 - accuracy: 1.0000 - mse: 0.1455
# Epoch 209/500
# 2/2 [==============================] - 0s 704us/step - loss: 0.1456 - accuracy: 1.0000 - mse: 0.1456
# Epoch 210/500
# 2/2 [==============================] - 0s 853us/step - loss: 0.1447 - accuracy: 1.0000 - mse: 0.1447
# Epoch 211/500
# 2/2 [==============================] - 0s 694us/step - loss: 0.1444 - accuracy: 1.0000 - mse: 0.1444
# Epoch 212/500
# 2/2 [==============================] - 0s 786us/step - loss: 0.1472 - accuracy: 1.0000 - mse: 0.1472
# Epoch 213/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1432 - accuracy: 1.0000 - mse: 0.1432
# Epoch 214/500
# 2/2 [==============================] - 0s 876us/step - loss: 0.1432 - accuracy: 1.0000 - mse: 0.1432
# Epoch 215/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1423 - accuracy: 1.0000 - mse: 0.1423
# Epoch 216/500
# 2/2 [==============================] - 0s 999us/step - loss: 0.1452 - accuracy: 1.0000 - mse: 0.1452
# Epoch 217/500
# 2/2 [==============================] - 0s 855us/step - loss: 0.1447 - accuracy: 1.0000 - mse: 0.1447
# Epoch 218/500
# 2/2 [==============================] - 0s 667us/step - loss: 0.1412 - accuracy: 1.0000 - mse: 0.1412
# Epoch 219/500
# 2/2 [==============================] - 0s 799us/step - loss: 0.1406 - accuracy: 1.0000 - mse: 0.1406
# Epoch 220/500
# 2/2 [==============================] - 0s 875us/step - loss: 0.1435 - accuracy: 1.0000 - mse: 0.1435
# Epoch 221/500
# 2/2 [==============================] - 0s 730us/step - loss: 0.1397 - accuracy: 1.0000 - mse: 0.1397
# Epoch 222/500
# 2/2 [==============================] - 0s 645us/step - loss: 0.1392 - accuracy: 1.0000 - mse: 0.1392
# Epoch 223/500
# 2/2 [==============================] - 0s 840us/step - loss: 0.1384 - accuracy: 1.0000 - mse: 0.1384
# Epoch 224/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1413 - accuracy: 1.0000 - mse: 0.1413
# Epoch 225/500
# 2/2 [==============================] - 0s 652us/step - loss: 0.1373 - accuracy: 1.0000 - mse: 0.1373
# Epoch 226/500
# 2/2 [==============================] - 0s 726us/step - loss: 0.1370 - accuracy: 1.0000 - mse: 0.1370
# Epoch 227/500
# 2/2 [==============================] - 0s 708us/step - loss: 0.1364 - accuracy: 1.0000 - mse: 0.1364
# Epoch 228/500
# 2/2 [==============================] - 0s 701us/step - loss: 0.1358 - accuracy: 1.0000 - mse: 0.1358
# Epoch 229/500
# 2/2 [==============================] - 0s 539us/step - loss: 0.1355 - accuracy: 1.0000 - mse: 0.1355
# Epoch 230/500
# 2/2 [==============================] - 0s 645us/step - loss: 0.1353 - accuracy: 1.0000 - mse: 0.1353
# Epoch 231/500
# 2/2 [==============================] - 0s 648us/step - loss: 0.1347 - accuracy: 1.0000 - mse: 0.1347
# Epoch 232/500
# 2/2 [==============================] - 0s 693us/step - loss: 0.1344 - accuracy: 1.0000 - mse: 0.1344
# Epoch 233/500
# 2/2 [==============================] - 0s 716us/step - loss: 0.1339 - accuracy: 1.0000 - mse: 0.1339
# Epoch 234/500
# 2/2 [==============================] - 0s 700us/step - loss: 0.1365 - accuracy: 1.0000 - mse: 0.1365
# Epoch 235/500
# 2/2 [==============================] - 0s 790us/step - loss: 0.1358 - accuracy: 1.0000 - mse: 0.1358
# Epoch 236/500
# 2/2 [==============================] - 0s 782us/step - loss: 0.1322 - accuracy: 1.0000 - mse: 0.1322
# Epoch 237/500
# 2/2 [==============================] - 0s 735us/step - loss: 0.1321 - accuracy: 1.0000 - mse: 0.1321
# Epoch 238/500
# 2/2 [==============================] - 0s 757us/step - loss: 0.1344 - accuracy: 1.0000 - mse: 0.1344
# Epoch 239/500
# 2/2 [==============================] - 0s 692us/step - loss: 0.1308 - accuracy: 1.0000 - mse: 0.1308
# Epoch 240/500
# 2/2 [==============================] - 0s 636us/step - loss: 0.1302 - accuracy: 1.0000 - mse: 0.1302
# Epoch 241/500
# 2/2 [==============================] - 0s 764us/step - loss: 0.1328 - accuracy: 1.0000 - mse: 0.1328
# Epoch 242/500
# 2/2 [==============================] - 0s 784us/step - loss: 0.1322 - accuracy: 1.0000 - mse: 0.1322
# Epoch 243/500
# 2/2 [==============================] - 0s 845us/step - loss: 0.1292 - accuracy: 1.0000 - mse: 0.1292
# Epoch 244/500
# 2/2 [==============================] - 0s 712us/step - loss: 0.1284 - accuracy: 1.0000 - mse: 0.1284
# Epoch 245/500
# 2/2 [==============================] - 0s 547us/step - loss: 0.1308 - accuracy: 1.0000 - mse: 0.1308
# Epoch 246/500
# 2/2 [==============================] - 0s 613us/step - loss: 0.1275 - accuracy: 1.0000 - mse: 0.1275
# Epoch 247/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1270 - accuracy: 1.0000 - mse: 0.1270
# Epoch 248/500
# 2/2 [==============================] - 0s 721us/step - loss: 0.1269 - accuracy: 1.0000 - mse: 0.1269
# Epoch 249/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1293 - accuracy: 1.0000 - mse: 0.1293
# Epoch 250/500
# 2/2 [==============================] - 0s 731us/step - loss: 0.1257 - accuracy: 1.0000 - mse: 0.1257
# Epoch 251/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1279 - accuracy: 1.0000 - mse: 0.1279
# Epoch 252/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1278 - accuracy: 1.0000 - mse: 0.1278
# Epoch 253/500
# 2/2 [==============================] - 0s 739us/step - loss: 0.1272 - accuracy: 1.0000 - mse: 0.1272
# Epoch 254/500
# 2/2 [==============================] - 0s 659us/step - loss: 0.1242 - accuracy: 1.0000 - mse: 0.1242
# Epoch 255/500
# 2/2 [==============================] - 0s 643us/step - loss: 0.1234 - accuracy: 1.0000 - mse: 0.1234
# Epoch 256/500
# 2/2 [==============================] - 0s 798us/step - loss: 0.1255 - accuracy: 1.0000 - mse: 0.1255
# Epoch 257/500
# 2/2 [==============================] - 0s 629us/step - loss: 0.1258 - accuracy: 1.0000 - mse: 0.1258
# Epoch 258/500
# 2/2 [==============================] - 0s 661us/step - loss: 0.1225 - accuracy: 1.0000 - mse: 0.1225
# Epoch 259/500
# 2/2 [==============================] - 0s 739us/step - loss: 0.1245 - accuracy: 1.0000 - mse: 0.1245
# Epoch 260/500
# 2/2 [==============================] - 0s 798us/step - loss: 0.1214 - accuracy: 1.0000 - mse: 0.1214
# Epoch 261/500
# 2/2 [==============================] - 0s 635us/step - loss: 0.1212 - accuracy: 1.0000 - mse: 0.1212
# Epoch 262/500
# 2/2 [==============================] - 0s 668us/step - loss: 0.1206 - accuracy: 1.0000 - mse: 0.1206
# Epoch 263/500
# 2/2 [==============================] - 0s 632us/step - loss: 0.1202 - accuracy: 1.0000 - mse: 0.1202
# Epoch 264/500
# 2/2 [==============================] - 0s 693us/step - loss: 0.1221 - accuracy: 1.0000 - mse: 0.1221
# Epoch 265/500
# 2/2 [==============================] - 0s 916us/step - loss: 0.1191 - accuracy: 1.0000 - mse: 0.1191
# Epoch 266/500
# 2/2 [==============================] - 0s 706us/step - loss: 0.1211 - accuracy: 1.0000 - mse: 0.1211
# Epoch 267/500
# 2/2 [==============================] - 0s 685us/step - loss: 0.1214 - accuracy: 1.0000 - mse: 0.1214
# Epoch 268/500
# 2/2 [==============================] - 0s 636us/step - loss: 0.1177 - accuracy: 1.0000 - mse: 0.1177
# Epoch 269/500
# 2/2 [==============================] - 0s 650us/step - loss: 0.1178 - accuracy: 1.0000 - mse: 0.1178
# Epoch 270/500
# 2/2 [==============================] - 0s 769us/step - loss: 0.1167 - accuracy: 1.0000 - mse: 0.1167
# Epoch 271/500
# 2/2 [==============================] - 0s 822us/step - loss: 0.1165 - accuracy: 1.0000 - mse: 0.1165
# Epoch 272/500
# 2/2 [==============================] - 0s 571us/step - loss: 0.1160 - accuracy: 1.0000 - mse: 0.1160
# Epoch 273/500
# 2/2 [==============================] - 0s 834us/step - loss: 0.1184 - accuracy: 1.0000 - mse: 0.1184
# Epoch 274/500
# 2/2 [==============================] - 0s 778us/step - loss: 0.1152 - accuracy: 1.0000 - mse: 0.1152
# Epoch 275/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1175 - accuracy: 1.0000 - mse: 0.1175
# Epoch 276/500
# 2/2 [==============================] - 0s 756us/step - loss: 0.1171 - accuracy: 1.0000 - mse: 0.1171
# Epoch 277/500
# 2/2 [==============================] - 0s 957us/step - loss: 0.1146 - accuracy: 1.0000 - mse: 0.1146
# Epoch 278/500
# 2/2 [==============================] - 0s 809us/step - loss: 0.1162 - accuracy: 1.0000 - mse: 0.1162
# Epoch 279/500
# 2/2 [==============================] - 0s 735us/step - loss: 0.1158 - accuracy: 1.0000 - mse: 0.1158
# Epoch 280/500
# 2/2 [==============================] - 0s 772us/step - loss: 0.1154 - accuracy: 1.0000 - mse: 0.1154
# Epoch 281/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1124 - accuracy: 1.0000 - mse: 0.1124
# Epoch 282/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1118 - accuracy: 1.0000 - mse: 0.1118
# Epoch 283/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.1142 - accuracy: 1.0000 - mse: 0.1142
# Epoch 284/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1109 - accuracy: 1.0000 - mse: 0.1109
# Epoch 285/500
# 2/2 [==============================] - 0s 765us/step - loss: 0.1111 - accuracy: 1.0000 - mse: 0.1111
# Epoch 286/500
# 2/2 [==============================] - 0s 934us/step - loss: 0.1106 - accuracy: 1.0000 - mse: 0.1106
# Epoch 287/500
# 2/2 [==============================] - 0s 637us/step - loss: 0.1097 - accuracy: 1.0000 - mse: 0.1097
# Epoch 288/500
# 2/2 [==============================] - 0s 651us/step - loss: 0.1095 - accuracy: 1.0000 - mse: 0.1095
# Epoch 289/500
# 2/2 [==============================] - 0s 638us/step - loss: 0.1115 - accuracy: 1.0000 - mse: 0.1115
# Epoch 290/500
# 2/2 [==============================] - 0s 691us/step - loss: 0.1085 - accuracy: 1.0000 - mse: 0.1085
# Epoch 291/500
# 2/2 [==============================] - 0s 794us/step - loss: 0.1111 - accuracy: 1.0000 - mse: 0.1111
# Epoch 292/500
# 2/2 [==============================] - 0s 733us/step - loss: 0.1078 - accuracy: 1.0000 - mse: 0.1078
# Epoch 293/500
# 2/2 [==============================] - 0s 771us/step - loss: 0.1078 - accuracy: 1.0000 - mse: 0.1078
# Epoch 294/500
# 2/2 [==============================] - 0s 598us/step - loss: 0.1096 - accuracy: 1.0000 - mse: 0.1096
# Epoch 295/500
# 2/2 [==============================] - 0s 677us/step - loss: 0.1071 - accuracy: 1.0000 - mse: 0.1071
# Epoch 296/500
# 2/2 [==============================] - 0s 606us/step - loss: 0.1085 - accuracy: 1.0000 - mse: 0.1085
# Epoch 297/500
# 2/2 [==============================] - 0s 784us/step - loss: 0.1086 - accuracy: 1.0000 - mse: 0.1086
# Epoch 298/500
# 2/2 [==============================] - 0s 797us/step - loss: 0.1079 - accuracy: 1.0000 - mse: 0.1079
# Epoch 299/500
# 2/2 [==============================] - 0s 701us/step - loss: 0.1050 - accuracy: 1.0000 - mse: 0.1050
# Epoch 300/500
# 2/2 [==============================] - 0s 718us/step - loss: 0.1050 - accuracy: 1.0000 - mse: 0.1050
# Epoch 301/500
# 2/2 [==============================] - 0s 807us/step - loss: 0.1042 - accuracy: 1.0000 - mse: 0.1042
# Epoch 302/500
# 2/2 [==============================] - 0s 646us/step - loss: 0.1061 - accuracy: 1.0000 - mse: 0.1061
# Epoch 303/500
# 2/2 [==============================] - 0s 676us/step - loss: 0.1061 - accuracy: 1.0000 - mse: 0.1061
# Epoch 304/500
# 2/2 [==============================] - 0s 751us/step - loss: 0.1054 - accuracy: 1.0000 - mse: 0.1054
# Epoch 305/500
# 2/2 [==============================] - 0s 679us/step - loss: 0.1029 - accuracy: 1.0000 - mse: 0.1029
# Epoch 306/500
# 2/2 [==============================] - 0s 719us/step - loss: 0.1025 - accuracy: 1.0000 - mse: 0.1025
# Epoch 307/500
# 2/2 [==============================] - 0s 589us/step - loss: 0.1018 - accuracy: 1.0000 - mse: 0.1018
# Epoch 308/500
# 2/2 [==============================] - 0s 720us/step - loss: 0.1014 - accuracy: 1.0000 - mse: 0.1014
# Epoch 309/500
# 2/2 [==============================] - 0s 731us/step - loss: 0.1009 - accuracy: 1.0000 - mse: 0.1009
# Epoch 310/500
# 2/2 [==============================] - 0s 674us/step - loss: 0.1034 - accuracy: 1.0000 - mse: 0.1034
# Epoch 311/500
# 2/2 [==============================] - 0s 726us/step - loss: 0.1002 - accuracy: 1.0000 - mse: 0.1002
# Epoch 312/500
# 2/2 [==============================] - 0s 719us/step - loss: 0.0998 - accuracy: 1.0000 - mse: 0.0998
# Epoch 313/500
# 2/2 [==============================] - 0s 969us/step - loss: 0.1022 - accuracy: 1.0000 - mse: 0.1022
# Epoch 314/500
# 2/2 [==============================] - 0s 740us/step - loss: 0.0992 - accuracy: 1.0000 - mse: 0.0992
# Epoch 315/500
# 2/2 [==============================] - 0s 835us/step - loss: 0.0987 - accuracy: 1.0000 - mse: 0.0987
# Epoch 316/500
# 2/2 [==============================] - 0s 854us/step - loss: 0.0987 - accuracy: 1.0000 - mse: 0.0987
# Epoch 317/500
# 2/2 [==============================] - 0s 887us/step - loss: 0.0984 - accuracy: 1.0000 - mse: 0.0984
# Epoch 318/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.1002 - accuracy: 1.0000 - mse: 0.1002
# Epoch 319/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0977 - accuracy: 1.0000 - mse: 0.0977
# Epoch 320/500
# 2/2 [==============================] - 0s 746us/step - loss: 0.0990 - accuracy: 1.0000 - mse: 0.0990
# Epoch 321/500
# 2/2 [==============================] - 0s 862us/step - loss: 0.0967 - accuracy: 1.0000 - mse: 0.0967
# Epoch 322/500
# 2/2 [==============================] - 0s 761us/step - loss: 0.0960 - accuracy: 1.0000 - mse: 0.0960
# Epoch 323/500
# 2/2 [==============================] - 0s 911us/step - loss: 0.0959 - accuracy: 1.0000 - mse: 0.0959
# Epoch 324/500
# 2/2 [==============================] - 0s 930us/step - loss: 0.0978 - accuracy: 1.0000 - mse: 0.0978
# Epoch 325/500
# 2/2 [==============================] - 0s 669us/step - loss: 0.0972 - accuracy: 1.0000 - mse: 0.0972
# Epoch 326/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0949 - accuracy: 1.0000 - mse: 0.0949
# Epoch 327/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0942 - accuracy: 1.0000 - mse: 0.0942
# Epoch 328/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0940 - accuracy: 1.0000 - mse: 0.0940
# Epoch 329/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0938 - accuracy: 1.0000 - mse: 0.0938
# Epoch 330/500
# 2/2 [==============================] - 0s 925us/step - loss: 0.0931 - accuracy: 1.0000 - mse: 0.0931
# Epoch 331/500
# 2/2 [==============================] - 0s 817us/step - loss: 0.0931 - accuracy: 1.0000 - mse: 0.0931
# Epoch 332/500
# 2/2 [==============================] - 0s 776us/step - loss: 0.0944 - accuracy: 1.0000 - mse: 0.0944
# Epoch 333/500
# 2/2 [==============================] - 0s 931us/step - loss: 0.0920 - accuracy: 1.0000 - mse: 0.0920
# Epoch 334/500
# 2/2 [==============================] - 0s 872us/step - loss: 0.0941 - accuracy: 1.0000 - mse: 0.0941
# Epoch 335/500
# 2/2 [==============================] - 0s 679us/step - loss: 0.0917 - accuracy: 1.0000 - mse: 0.0917
# Epoch 336/500
# 2/2 [==============================] - 0s 909us/step - loss: 0.0909 - accuracy: 1.0000 - mse: 0.0909
# Epoch 337/500
# 2/2 [==============================] - 0s 840us/step - loss: 0.0908 - accuracy: 1.0000 - mse: 0.0908
# Epoch 338/500
# 2/2 [==============================] - 0s 795us/step - loss: 0.0926 - accuracy: 1.0000 - mse: 0.0926
# Epoch 339/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0898 - accuracy: 1.0000 - mse: 0.0898
# Epoch 340/500
# 2/2 [==============================] - 0s 610us/step - loss: 0.0916 - accuracy: 1.0000 - mse: 0.0916
# Epoch 341/500
# 2/2 [==============================] - 0s 772us/step - loss: 0.0892 - accuracy: 1.0000 - mse: 0.0892
# Epoch 342/500
# 2/2 [==============================] - 0s 819us/step - loss: 0.0887 - accuracy: 1.0000 - mse: 0.0887
# Epoch 343/500
# 2/2 [==============================] - 0s 591us/step - loss: 0.0887 - accuracy: 1.0000 - mse: 0.0887
# Epoch 344/500
# 2/2 [==============================] - 0s 845us/step - loss: 0.0880 - accuracy: 1.0000 - mse: 0.0880
# Epoch 345/500
# 2/2 [==============================] - 0s 701us/step - loss: 0.0876 - accuracy: 1.0000 - mse: 0.0876
# Epoch 346/500
# 2/2 [==============================] - 0s 807us/step - loss: 0.0874 - accuracy: 1.0000 - mse: 0.0874
# Epoch 347/500
# 2/2 [==============================] - 0s 954us/step - loss: 0.0869 - accuracy: 1.0000 - mse: 0.0869
# Epoch 348/500
# 2/2 [==============================] - 0s 973us/step - loss: 0.0869 - accuracy: 1.0000 - mse: 0.0869
# Epoch 349/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0860 - accuracy: 1.0000 - mse: 0.0860
# Epoch 350/500
# 2/2 [==============================] - 0s 787us/step - loss: 0.0885 - accuracy: 1.0000 - mse: 0.0885
# Epoch 351/500
# 2/2 [==============================] - 0s 788us/step - loss: 0.0856 - accuracy: 1.0000 - mse: 0.0856
# Epoch 352/500
# 2/2 [==============================] - 0s 858us/step - loss: 0.0872 - accuracy: 1.0000 - mse: 0.0872
# Epoch 353/500
# 2/2 [==============================] - 0s 784us/step - loss: 0.0870 - accuracy: 1.0000 - mse: 0.0870
# Epoch 354/500
# 2/2 [==============================] - 0s 805us/step - loss: 0.0849 - accuracy: 1.0000 - mse: 0.0849
# Epoch 355/500
# 2/2 [==============================] - 0s 900us/step - loss: 0.0840 - accuracy: 1.0000 - mse: 0.0840
# Epoch 356/500
# 2/2 [==============================] - 0s 785us/step - loss: 0.0839 - accuracy: 1.0000 - mse: 0.0839
# Epoch 357/500
# 2/2 [==============================] - 0s 835us/step - loss: 0.0857 - accuracy: 1.0000 - mse: 0.0857
# Epoch 358/500
# 2/2 [==============================] - 0s 710us/step - loss: 0.0830 - accuracy: 1.0000 - mse: 0.0830
# Epoch 359/500
# 2/2 [==============================] - 0s 848us/step - loss: 0.0847 - accuracy: 1.0000 - mse: 0.0847
# Epoch 360/500
# 2/2 [==============================] - 0s 786us/step - loss: 0.0822 - accuracy: 1.0000 - mse: 0.0822
# Epoch 361/500
# 2/2 [==============================] - 0s 854us/step - loss: 0.0843 - accuracy: 1.0000 - mse: 0.0843
# Epoch 362/500
# 2/2 [==============================] - 0s 955us/step - loss: 0.0835 - accuracy: 1.0000 - mse: 0.0835
# Epoch 363/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0835 - accuracy: 1.0000 - mse: 0.0835
# Epoch 364/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0810 - accuracy: 1.0000 - mse: 0.0810
# Epoch 365/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0807 - accuracy: 1.0000 - mse: 0.0807
# Epoch 366/500
# 2/2 [==============================] - 0s 812us/step - loss: 0.0802 - accuracy: 1.0000 - mse: 0.0802
# Epoch 367/500
# 2/2 [==============================] - 0s 871us/step - loss: 0.0801 - accuracy: 1.0000 - mse: 0.0801
# Epoch 368/500
# 2/2 [==============================] - 0s 647us/step - loss: 0.0819 - accuracy: 1.0000 - mse: 0.0819
# Epoch 369/500
# 2/2 [==============================] - 0s 702us/step - loss: 0.0796 - accuracy: 1.0000 - mse: 0.0796
# Epoch 370/500
# 2/2 [==============================] - 0s 708us/step - loss: 0.0813 - accuracy: 1.0000 - mse: 0.0813
# Epoch 371/500
# 2/2 [==============================] - 0s 766us/step - loss: 0.0790 - accuracy: 1.0000 - mse: 0.0790
# Epoch 372/500
# 2/2 [==============================] - 0s 791us/step - loss: 0.0784 - accuracy: 1.0000 - mse: 0.0784
# Epoch 373/500
# 2/2 [==============================] - 0s 944us/step - loss: 0.0779 - accuracy: 1.0000 - mse: 0.0779
# Epoch 374/500
# 2/2 [==============================] - 0s 852us/step - loss: 0.0777 - accuracy: 1.0000 - mse: 0.0777
# Epoch 375/500
# 2/2 [==============================] - 0s 884us/step - loss: 0.0777 - accuracy: 1.0000 - mse: 0.0777
# Epoch 376/500
# 2/2 [==============================] - 0s 752us/step - loss: 0.0774 - accuracy: 1.0000 - mse: 0.0774
# Epoch 377/500
# 2/2 [==============================] - 0s 883us/step - loss: 0.0766 - accuracy: 1.0000 - mse: 0.0766
# Epoch 378/500
# 2/2 [==============================] - 0s 874us/step - loss: 0.0764 - accuracy: 1.0000 - mse: 0.0764
# Epoch 379/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0763 - accuracy: 1.0000 - mse: 0.0763
# Epoch 380/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0760 - accuracy: 1.0000 - mse: 0.0760
# Epoch 381/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0755 - accuracy: 1.0000 - mse: 0.0755
# Epoch 382/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0752 - accuracy: 1.0000 - mse: 0.0752
# Epoch 383/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0768 - accuracy: 1.0000 - mse: 0.0768
# Epoch 384/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0746 - accuracy: 1.0000 - mse: 0.0746
# Epoch 385/500
# 2/2 [==============================] - 0s 909us/step - loss: 0.0760 - accuracy: 1.0000 - mse: 0.0760
# Epoch 386/500
# 2/2 [==============================] - 0s 953us/step - loss: 0.0740 - accuracy: 1.0000 - mse: 0.0740
# Epoch 387/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0738 - accuracy: 1.0000 - mse: 0.0738
# Epoch 388/500
# 2/2 [==============================] - 0s 831us/step - loss: 0.0734 - accuracy: 1.0000 - mse: 0.0734
# Epoch 389/500
# 2/2 [==============================] - 0s 842us/step - loss: 0.0728 - accuracy: 1.0000 - mse: 0.0728
# Epoch 390/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0729 - accuracy: 1.0000 - mse: 0.0729
# Epoch 391/500
# 2/2 [==============================] - 0s 794us/step - loss: 0.0741 - accuracy: 1.0000 - mse: 0.0741
# Epoch 392/500
# 2/2 [==============================] - 0s 850us/step - loss: 0.0739 - accuracy: 1.0000 - mse: 0.0739
# Epoch 393/500
# 2/2 [==============================] - 0s 888us/step - loss: 0.0734 - accuracy: 1.0000 - mse: 0.0734
# Epoch 394/500
# 2/2 [==============================] - 0s 729us/step - loss: 0.0717 - accuracy: 1.0000 - mse: 0.0717
# Epoch 395/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0711 - accuracy: 1.0000 - mse: 0.0711
# Epoch 396/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0708 - accuracy: 1.0000 - mse: 0.0708
# Epoch 397/500
# 2/2 [==============================] - 0s 785us/step - loss: 0.0707 - accuracy: 1.0000 - mse: 0.0707
# Epoch 398/500
# 2/2 [==============================] - 0s 870us/step - loss: 0.0703 - accuracy: 1.0000 - mse: 0.0703
# Epoch 399/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0698 - accuracy: 1.0000 - mse: 0.0698
# Epoch 400/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0713 - accuracy: 1.0000 - mse: 0.0713
# Epoch 401/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0693 - accuracy: 1.0000 - mse: 0.0693
# Epoch 402/500
# 2/2 [==============================] - 0s 889us/step - loss: 0.0689 - accuracy: 1.0000 - mse: 0.0689
# Epoch 403/500
# 2/2 [==============================] - 0s 796us/step - loss: 0.0690 - accuracy: 1.0000 - mse: 0.0690
# Epoch 404/500
# 2/2 [==============================] - 0s 946us/step - loss: 0.0686 - accuracy: 1.0000 - mse: 0.0686
# Epoch 405/500
# 2/2 [==============================] - 0s 826us/step - loss: 0.0696 - accuracy: 1.0000 - mse: 0.0696
# Epoch 406/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0679 - accuracy: 1.0000 - mse: 0.0679
# Epoch 407/500
# 2/2 [==============================] - 0s 902us/step - loss: 0.0674 - accuracy: 1.0000 - mse: 0.0674
# Epoch 408/500
# 2/2 [==============================] - 0s 737us/step - loss: 0.0690 - accuracy: 1.0000 - mse: 0.0690
# Epoch 409/500
# 2/2 [==============================] - 0s 792us/step - loss: 0.0669 - accuracy: 1.0000 - mse: 0.0669
# Epoch 410/500
# 2/2 [==============================] - 0s 819us/step - loss: 0.0669 - accuracy: 1.0000 - mse: 0.0669
# Epoch 411/500
# 2/2 [==============================] - 0s 721us/step - loss: 0.0665 - accuracy: 1.0000 - mse: 0.0665
# Epoch 412/500
# 2/2 [==============================] - 0s 878us/step - loss: 0.0674 - accuracy: 1.0000 - mse: 0.0674
# Epoch 413/500
# 2/2 [==============================] - 0s 791us/step - loss: 0.0660 - accuracy: 1.0000 - mse: 0.0660
# Epoch 414/500
# 2/2 [==============================] - 0s 845us/step - loss: 0.0656 - accuracy: 1.0000 - mse: 0.0656
# Epoch 415/500
# 2/2 [==============================] - 0s 942us/step - loss: 0.0651 - accuracy: 1.0000 - mse: 0.0651
# Epoch 416/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0667 - accuracy: 1.0000 - mse: 0.0667
# Epoch 417/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0660 - accuracy: 1.0000 - mse: 0.0660
# Epoch 418/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0656 - accuracy: 1.0000 - mse: 0.0656
# Epoch 419/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0640 - accuracy: 1.0000 - mse: 0.0640
# Epoch 420/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0637 - accuracy: 1.0000 - mse: 0.0637
# Epoch 421/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0636 - accuracy: 1.0000 - mse: 0.0636
# Epoch 422/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0632 - accuracy: 1.0000 - mse: 0.0632
# Epoch 423/500
# 2/2 [==============================] - 0s 679us/step - loss: 0.0631 - accuracy: 1.0000 - mse: 0.0631
# Epoch 424/500
# 2/2 [==============================] - 0s 959us/step - loss: 0.0640 - accuracy: 1.0000 - mse: 0.0640
# Epoch 425/500
# 2/2 [==============================] - 0s 988us/step - loss: 0.0623 - accuracy: 1.0000 - mse: 0.0623
# Epoch 426/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0637 - accuracy: 1.0000 - mse: 0.0637
# Epoch 427/500
# 2/2 [==============================] - 0s 799us/step - loss: 0.0618 - accuracy: 1.0000 - mse: 0.0618
# Epoch 428/500
# 2/2 [==============================] - 0s 960us/step - loss: 0.0615 - accuracy: 1.0000 - mse: 0.0615
# Epoch 429/500
# 2/2 [==============================] - 0s 980us/step - loss: 0.0612 - accuracy: 1.0000 - mse: 0.0612
# Epoch 430/500
# 2/2 [==============================] - 0s 883us/step - loss: 0.0612 - accuracy: 1.0000 - mse: 0.0612
# Epoch 431/500
# 2/2 [==============================] - 0s 826us/step - loss: 0.0606 - accuracy: 1.0000 - mse: 0.0606
# Epoch 432/500
# 2/2 [==============================] - 0s 840us/step - loss: 0.0603 - accuracy: 1.0000 - mse: 0.0603
# Epoch 433/500
# 2/2 [==============================] - 0s 707us/step - loss: 0.0601 - accuracy: 1.0000 - mse: 0.0601
# Epoch 434/500
# 2/2 [==============================] - 0s 676us/step - loss: 0.0600 - accuracy: 1.0000 - mse: 0.0600
# Epoch 435/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0609 - accuracy: 1.0000 - mse: 0.0609
# Epoch 436/500
# 2/2 [==============================] - 0s 652us/step - loss: 0.0593 - accuracy: 1.0000 - mse: 0.0593
# Epoch 437/500
# 2/2 [==============================] - 0s 822us/step - loss: 0.0590 - accuracy: 1.0000 - mse: 0.0590
# Epoch 438/500
# 2/2 [==============================] - 0s 822us/step - loss: 0.0589 - accuracy: 1.0000 - mse: 0.0589
# Epoch 439/500
# 2/2 [==============================] - 0s 986us/step - loss: 0.0599 - accuracy: 1.0000 - mse: 0.0599
# Epoch 440/500
# 2/2 [==============================] - 0s 747us/step - loss: 0.0595 - accuracy: 1.0000 - mse: 0.0595
# Epoch 441/500
# 2/2 [==============================] - 0s 904us/step - loss: 0.0580 - accuracy: 1.0000 - mse: 0.0580
# Epoch 442/500
# 2/2 [==============================] - 0s 812us/step - loss: 0.0578 - accuracy: 1.0000 - mse: 0.0578
# Epoch 443/500
# 2/2 [==============================] - 0s 816us/step - loss: 0.0575 - accuracy: 1.0000 - mse: 0.0575
# Epoch 444/500
# 2/2 [==============================] - 0s 938us/step - loss: 0.0587 - accuracy: 1.0000 - mse: 0.0587
# Epoch 445/500
# 2/2 [==============================] - 0s 711us/step - loss: 0.0581 - accuracy: 1.0000 - mse: 0.0581
# Epoch 446/500
# 2/2 [==============================] - 0s 739us/step - loss: 0.0568 - accuracy: 1.0000 - mse: 0.0568
# Epoch 447/500
# 2/2 [==============================] - 0s 710us/step - loss: 0.0565 - accuracy: 1.0000 - mse: 0.0565
# Epoch 448/500
# 2/2 [==============================] - 0s 720us/step - loss: 0.0562 - accuracy: 1.0000 - mse: 0.0562
# Epoch 449/500
# 2/2 [==============================] - 0s 899us/step - loss: 0.0559 - accuracy: 1.0000 - mse: 0.0559
# Epoch 450/500
# 2/2 [==============================] - 0s 878us/step - loss: 0.0571 - accuracy: 1.0000 - mse: 0.0571
# Epoch 451/500
# 2/2 [==============================] - 0s 771us/step - loss: 0.0557 - accuracy: 1.0000 - mse: 0.0557
# Epoch 452/500
# 2/2 [==============================] - 0s 639us/step - loss: 0.0553 - accuracy: 1.0000 - mse: 0.0553
# Epoch 453/500
# 2/2 [==============================] - 0s 790us/step - loss: 0.0560 - accuracy: 1.0000 - mse: 0.0560
# Epoch 454/500
# 2/2 [==============================] - 0s 892us/step - loss: 0.0547 - accuracy: 1.0000 - mse: 0.0547
# Epoch 455/500
# 2/2 [==============================] - 0s 855us/step - loss: 0.0556 - accuracy: 1.0000 - mse: 0.0556
# Epoch 456/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0553 - accuracy: 1.0000 - mse: 0.0553
# Epoch 457/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0539 - accuracy: 1.0000 - mse: 0.0539
# Epoch 458/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0547 - accuracy: 1.0000 - mse: 0.0547
# Epoch 459/500
# 2/2 [==============================] - 0s 757us/step - loss: 0.0548 - accuracy: 1.0000 - mse: 0.0548
# Epoch 460/500
# 2/2 [==============================] - 0s 896us/step - loss: 0.0531 - accuracy: 1.0000 - mse: 0.0531
# Epoch 461/500
# 2/2 [==============================] - 0s 949us/step - loss: 0.0542 - accuracy: 1.0000 - mse: 0.0542
# Epoch 462/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0526 - accuracy: 1.0000 - mse: 0.0526
# Epoch 463/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0524 - accuracy: 1.0000 - mse: 0.0524
# Epoch 464/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0520 - accuracy: 1.0000 - mse: 0.0520
# Epoch 465/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0519 - accuracy: 1.0000 - mse: 0.0519
# Epoch 466/500
# 2/2 [==============================] - 0s 934us/step - loss: 0.0518 - accuracy: 1.0000 - mse: 0.0518
# Epoch 467/500
# 2/2 [==============================] - 0s 2ms/step - loss: 0.0514 - accuracy: 1.0000 - mse: 0.0514
# Epoch 468/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0525 - accuracy: 1.0000 - mse: 0.0525
# Epoch 469/500
# 2/2 [==============================] - 0s 681us/step - loss: 0.0520 - accuracy: 1.0000 - mse: 0.0520
# Epoch 470/500
# 2/2 [==============================] - 0s 834us/step - loss: 0.0518 - accuracy: 1.0000 - mse: 0.0518
# Epoch 471/500
# 2/2 [==============================] - 0s 804us/step - loss: 0.0514 - accuracy: 1.0000 - mse: 0.0514
# Epoch 472/500
# 2/2 [==============================] - 0s 781us/step - loss: 0.0503 - accuracy: 1.0000 - mse: 0.0503
# Epoch 473/500
# 2/2 [==============================] - 0s 858us/step - loss: 0.0501 - accuracy: 1.0000 - mse: 0.0501
# Epoch 474/500
# 2/2 [==============================] - 0s 887us/step - loss: 0.0498 - accuracy: 1.0000 - mse: 0.0498
# Epoch 475/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0496 - accuracy: 1.0000 - mse: 0.0496
# Epoch 476/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0492 - accuracy: 1.0000 - mse: 0.0492
# Epoch 477/500
# 2/2 [==============================] - 0s 889us/step - loss: 0.0492 - accuracy: 1.0000 - mse: 0.0492
# Epoch 478/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0490 - accuracy: 1.0000 - mse: 0.0490
# Epoch 479/500
# 2/2 [==============================] - 0s 824us/step - loss: 0.0497 - accuracy: 1.0000 - mse: 0.0497
# Epoch 480/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0485 - accuracy: 1.0000 - mse: 0.0485
# Epoch 481/500
# 2/2 [==============================] - 0s 872us/step - loss: 0.0483 - accuracy: 1.0000 - mse: 0.0483
# Epoch 482/500
# 2/2 [==============================] - 0s 1ms/step - loss: 0.0479 - accuracy: 1.0000 - mse: 0.0479
# Epoch 483/500
# 2/2 [==============================] - 0s 863us/step - loss: 0.0489 - accuracy: 1.0000 - mse: 0.0489
# Epoch 484/500
# 2/2 [==============================] - 0s 828us/step - loss: 0.0474 - accuracy: 1.0000 - mse: 0.0474
# Epoch 485/500
# 2/2 [==============================] - 0s 726us/step - loss: 0.0474 - accuracy: 1.0000 - mse: 0.0474
# Epoch 486/500
# 2/2 [==============================] - 0s 802us/step - loss: 0.0479 - accuracy: 1.0000 - mse: 0.0479
# Epoch 487/500
# 2/2 [==============================] - 0s 753us/step - loss: 0.0467 - accuracy: 1.0000 - mse: 0.0467
# Epoch 488/500
# 2/2 [==============================] - 0s 805us/step - loss: 0.0478 - accuracy: 1.0000 - mse: 0.0478
# Epoch 489/500
# 2/2 [==============================] - 0s 772us/step - loss: 0.0466 - accuracy: 1.0000 - mse: 0.0466
# Epoch 490/500
# 2/2 [==============================] - 0s 757us/step - loss: 0.0471 - accuracy: 1.0000 - mse: 0.0471
# Epoch 491/500
# 2/2 [==============================] - 0s 735us/step - loss: 0.0471 - accuracy: 1.0000 - mse: 0.0471
# Epoch 492/500
# 2/2 [==============================] - 0s 891us/step - loss: 0.0459 - accuracy: 1.0000 - mse: 0.0459
# Epoch 493/500
# 2/2 [==============================] - 0s 814us/step - loss: 0.0465 - accuracy: 1.0000 - mse: 0.0465
# Epoch 494/500
# 2/2 [==============================] - 0s 877us/step - loss: 0.0462 - accuracy: 1.0000 - mse: 0.0462
# Epoch 495/500
# 2/2 [==============================] - 0s 960us/step - loss: 0.0450 - accuracy: 1.0000 - mse: 0.0450
# Epoch 496/500
# 2/2 [==============================] - 0s 792us/step - loss: 0.0447 - accuracy: 1.0000 - mse: 0.0447
# Epoch 497/500
# 2/2 [==============================] - 0s 992us/step - loss: 0.0447 - accuracy: 1.0000 - mse: 0.0447
# Epoch 498/500
# 2/2 [==============================] - 0s 933us/step - loss: 0.0444 - accuracy: 1.0000 - mse: 0.0444
# Epoch 499/500
# 2/2 [==============================] - 0s 930us/step - loss: 0.0442 - accuracy: 1.0000 - mse: 0.0442
# Epoch 500/500
# 2/2 [==============================] - 0s 804us/step - loss: 0.0439 - accuracy: 1.0000 - mse: 0.0439

# %% [markdown]
# It is worth exploring the number of epochs. If you do this you will quickly discover that running too few epochs will sometimes lead to a network that does not converge to a solution with perfect accuracy.
#
# Keep in mind this data set is somewhat artificial - for exampl consisting of four examples. The simplicity of the data set noted, it is entirely sufficient to start trying out the basics.
#
# There are a few tools we can use to look at the network as well.  ```summary``` will provide an overview of the network, including how many parameters are used.  The ```None``` in the Output Shape column corresponds to the number of input values fed through the network.  ```summary``` must be called *after* ```fit```.

# %%
network1.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_16 (Dense)            (None, 10)                30
#
#  dense_17 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# If we want to look at the actual weights used by the network, we can use the ```layers``` attribute of the network:

# %%
network1.layers
# Out:
# [<keras.layers.core.dense.Dense at 0x297b18550>,
#  <keras.layers.core.dense.Dense at 0x297b18160>]

# %% [markdown]
# Each of the elements in this list represents a layer of the network; here's what we need to do to see the actual values:

# %%
network1.layers[0].weights
# Out:
# [<tf.Variable 'dense_8/kernel:0' shape=(2, 10) dtype=float32, numpy=
#  array([[ 0.47610646, -0.23304561, -0.52042806, -0.40998387,  0.19605826,
#           0.42265537, -0.50433016,  0.41764903,  0.06819497, -0.04524964],
#         [-0.46863067, -0.07373828,  0.12180707,  0.40980828,  0.31952098,
#           0.47501656, -0.5761538 , -0.05902389,  0.36246058, -0.5679097 ]],
#        dtype=float32)>,
#  <tf.Variable 'dense_8/bias:0' shape=(10,) dtype=float32, numpy=
#  array([-5.9749917e-03,  0.0000000e+00, -1.2375718e-01, -4.5907946e-05,
#          7.5752533e-04,  1.2084411e-01,  0.0000000e+00,  1.1351461e-01,
#          1.3998871e-01,  5.6000069e-02], dtype=float32)>]

# %% [markdown]
# And here's the next layer:

# %%
print(network1.layers[1].weights)
# Out:
# [<tf.Variable 'dense_9/kernel:0' shape=(10, 1) dtype=float32, numpy=
# array([[-0.7307266 ],
#        [ 0.06452942],
#        [ 0.6780378 ],
#        [-0.4601224 ],
#        [-0.5547982 ],
#        [ 0.23165558],
#        [ 0.16733366],
#        [ 0.27631938],
#        [ 0.29091024],
#        [ 0.11561434]], dtype=float32)>, <tf.Variable 'dense_9/bias:0' shape=(1,) dtype=float32, numpy=array([0.43744496], dtype=float32)>]

# %% [markdown]
# To retrieve the weights, use the `get_weights()` method:

# %%
network1.layers[1].get_weights()
# Out:
# [array([[-0.7307266 ],
#         [ 0.06452942],
#         [ 0.6780378 ],
#         [-0.4601224 ],
#         [-0.5547982 ],
#         [ 0.23165558],
#         [ 0.16733366],
#         [ 0.27631938],
#         [ 0.29091024],
#         [ 0.11561434]], dtype=float32),
#  array([0.43744496], dtype=float32)]

# %% [markdown]
# We can also use the network for prediction:

# %%
print(network1.predict(X_xor))
# Out:
# 1/1 [==============================] - 0s 18ms/step
# [[0.54358375]
#  [0.3191955 ]
#  [0.3704731 ]
#  [0.6822982 ]]

# %% [markdown]
# Remember that the network is trying to approximate the values [1, 0, 0, 1].  Let's look at the history of the loss and accuracy over the epochs of training the network using the ```history``` of the trained network:

# %%
plt.plot(history1.history['accuracy'], label='Accuracy')
plt.plot(history1.history['mse'], label='MSE')
plt.ylim([0, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %% [markdown]
# Let's also look at the decision surface of this network:

# %%
plot_XOR_network(network1)
# Out:
# 458/458 [==============================] - 0s 212us/step

# %% [markdown]
# We can also add more layers and have more nodes in each layer:

# %%
network2 = tf.keras.Sequential()
network2.add(tf.keras.layers.Dense(50, activation='relu'))
network2.add(tf.keras.layers.Dense(25, activation='relu'))
network2.add(tf.keras.layers.Dense(12, activation='relu'))
network2.add(tf.keras.layers.Dense(1))

loss_fn = tf.keras.losses.MeanSquaredError()
opt = tf.keras.optimizers.SGD(learning_rate=0.005)
network2.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])

history2 = network2.fit(X_xor, y_xor, batch_size=2, epochs=500, verbose=0)

# %%
network2.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (2, 50)                   150
#
#  dense_11 (Dense)            (2, 25)                   1275
#
#  dense_12 (Dense)            (2, 12)                   312
#
#  dense_13 (Dense)            (2, 1)                    13
#
# =================================================================
# Total params: 1,750
# Trainable params: 1,750
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# This model has far more complexity than is necessary for this problem - a total of 1,750 parameters is orders of magnitude larger than necessary, but it still finds a good solution.

# %%
plt.plot(history2.history['accuracy'], label='Accuracy')
plt.plot(history2.history['mse'], label='MSE')
plt.ylim([-0.1, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %%
plot_XOR_network(network2)
# Out:
# 458/458 [==============================] - 0s 218us/step

# %% [markdown]
# ## Loss Functions and Softmax

# %% [markdown]
# The squared error loss probably isn't the best loss function to be using: it is designed for regression problems. Instead, we can use the cross entropy loss.  To do this, one thing we need to do is change our expected outputs from being 0 or 1 to be "one-hot-encoded:"

# %%
y_xor_one_hot = tf.keras.utils.to_categorical(y_xor, 2)
print(y_xor_one_hot)
# Out:
# [[0. 1.]
#  [1. 0.]
#  [1. 0.]
#  [0. 1.]]

# %% [markdown]
# In one-hot-encoding, each output is now a vector with zero at each class label that is not correct for the associated input and one at the class label that is correct.  One thing to note with this modification is that our network will now have two outputs.
#
# It's also useful to restrict the outputs of our network to look like probabilities.  One way to do this would be to normalize the outputs to be
# \begin{align*}
# z_1' &= \frac{z_1}{z_1 + z_2} \\
# z_2' &= \frac{z_2}{z_1 + z_2}
# \end{align*}
# which gives us $z_1'$ and $z_2'$ values each between zero and one and summing to one.  One thing to keep in mind here is that although these now form a probability distribution, it isn't necessarily accurate to view $z_1'$ as the "probability that the input is of class one" because the approximation given by our network may not be a perfect statistical model of that fact.
#
# Another way to do this would be to take the hard max of the outputs,
# \begin{align*}
# z_1' &= \begin{cases} 1 & z_1 \geq z_2 \\ 0 & z_1 < z_2 \end{cases} \\
# z_2' &= \begin{cases} 0 & z_1 \geq z_2 \\ 1 & z_1 < z_2 \end{cases},
# \end{align*}
# which has similar nice properties but is unfortunately not differentiable, so we can't actually use it for classification.
#
# A comprimise between these two is softmax.  For our two raw outputs, $z_1$ and $z_2$, the softmax activation function is calculated as
# \begin{align*}
# \text{softmax}(z_1) &= \frac{e^{z_1}}{e^{z_1} + e^{z_2}} \\
# \text{softmax}(z_2) &= \frac{e^{z_2}}{e^{z_1} + e^{z_2}}
# \end{align*}
# This is very similar to normalization, but with the exponential function of the raw inputs instead.  This means that values will be driven to behave more similarly to the hardmax while still maintaining differentiability

# %% [markdown]
# ### Visualizing the effect of the softmax function
#
# Here is a simple bit of code to help you visualize what happens when the activations on the last layer of a classification network are run through the softmax function:

# %%
def apply_softmax(acts) :
    exp_acts = np.array([np.exp(x) for x in acts])
    exp_acts_sum = np.sum(exp_acts)
    acts_smax = np.array([np.exp(x)/exp_acts_sum for x in acts])
    return exp_acts, acts_smax

def visualize_softmax(mean, sigma, nsamples, rseed) :
    rng = np.random.default_rng(rseed)
    act = rng.normal(mean, sigma, nsamples)
    aex, asf = apply_softmax(act)
    plt.style.use('seaborn-deep')
    fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(13,5))
    ax1.bar(range(nsamples), act, color='darkred')
    ax1.set_xlabel('Output Node')
    ax1.set_ylabel('Activation')
    ax1.set_title('Input Activations')   
    ax2.bar(range(nsamples), aex, color='darkblue')
    ax2.set_xlabel('Output Node')
    ax2.set_ylabel('After Exponentiation')
    ax2.set_title('Exponentiated Input Activation')  
    ax3.bar(range(nsamples), asf, color='darkgreen')
    ax3.set_xlabel('Output Node')
    ax3.set_ylabel('Activation')
    ax3.set_title('Softmax applied to Activations')

# %%
visualize_softmax(5, 1.0, 8, 82)
# Out:
# /var/folders/z_/bvzqsp_10gl08jfkxfl5w2040000gn/T/ipykernel_98458/2307433303.py:11: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-deep')

# %% [markdown]
# In the network below we use the ```BinaryCrossentropy``` loss function  which is cross entropy for two classes with a softmax activation on our output layer.

# %%
network3 = tf.keras.Sequential()
network3.add(tf.keras.layers.Dense(10, activation='relu'))
network3.add(tf.keras.layers.Dense(2, activation='softmax'))

loss_fn = tf.keras.losses.BinaryCrossentropy()
opt = tf.keras.optimizers.SGD(learning_rate=0.01)
network3.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])

# %%
history3 = network3.fit(X_xor, y_xor_one_hot, batch_size=2, epochs=600, verbose=0)

# %%
plt.plot(history3.history['accuracy'], label='Accuracy')
plt.plot(history3.history['mse'], label='MSE')
plt.ylim([-0.1, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %% [markdown]
# To visualize the decision surface, we will plot $z_1 - z_2$.  This is a trick we will use throughout the rest of the notebook.

# %%
plot_XOR_network(network3, two_outputs=True)
# Out:
# 458/458 [==============================] - 0s 191us/step

# %% [markdown]
# ## Nonconvex Optimization

# %% [markdown]
# For linear models, finding a solution that minimizes some quantity of interest was relatively easy because the error surface has a single global minimum.  Whenever the error function satisfies a certain condition known as "convexity", this is guaranteed to be the case.
# Here's an example of a loss surface of a convex problem:

# %%
x = np.linspace(-10, 10, 1000)
y = np.power(x, 2)
points = np.r_[True, y[1:] <= y[:-1]] & np.r_[y[:-1] <= y[1:], True]
plt.plot(x, y, label='Loss Surface')
plt.xlabel('"Weight space"')
plt.ylabel('loss')
plt.title("Convex Optimization")
plt.xticks([])
plt.yticks([])
plt.scatter(x[points], y[points], c='r', label='minimum')
plt.legend();

# %% [markdown]
# As we change the weights of the model, we move around on the blue curve.  The goal is to find a configuration of weights that places us at the location of the red dot, which is the minimum of this function.

# %% [markdown]
# However, due to the nonlinearity of neural networks, there may be more than one minimum.  For example:

# %%
x = np.linspace(-10, 10, 1000)
y = np.power(x, 2) + 5*np.sin(np.pi*x)
points = np.r_[True, y[1:] < y[:-1]] & np.r_[y[:-1] < y[1:], True]
plt.plot(x, y, label="Loss Surface")
plt.xlabel('"Weight space"')
plt.ylabel('loss')
plt.xticks([])
plt.yticks([])
plt.title("Nonconvex Optimization")
plt.scatter(x[points], y[points], c='r', label='minima')
plt.legend();

# %% [markdown]
# In this case, there is a single global minimum that represents the optimal solution, but there are a number of other *local* minima.
#
# Gradient descent and many of its variants are the most commonly used algorithms for optimizing the weights of neural networks.  Gradient descent can be thought of as behaving like a ball that is placed on the the loss surface - it rolls down hills.  That means that if an initial configuration of a neural network lies somewhere in a valley around one of the local minima, gradient descent will push it towards that local minimum rather than the global minimum.
# However, that may or may not be a problem!  We are interested in solutions that have high prediction accuracy - not necessarily finding the global minimum.

# %% [markdown]
# ## Gradient Descent Modifications and Regularization

# %% [markdown]
# The simple SGD algorithm has a modification that can help with shallow local minima and plateaus in the loss surface - momentum.  Intuitively, this is the same as the idea would be in physics, where the model builds momentum as it travels, and can continue to follow that momentum rather than just going in the direction of most change.  This helps avoid shallow local minima and can prevent the model from slowing down too much on plateaus.

# %%
opt = tf.keras.optimizers.SGD(learning_rate=0.1, momentum=0.9)

# %% [markdown]
# We can also add weight decay to our model, where weights are driven towards small values to reduce the likelihood of overfitting and smooth the loss surface:

# %%
reg = tf.keras.regularizers.l2(1e-4)
network4 = tf.keras.Sequential()
network4.add(tf.keras.layers.Dense(10, activation='relu', kernel_regularizer=reg, bias_regularizer=reg))
network4.add(tf.keras.layers.Dense(2, activation='softmax', kernel_regularizer=reg, bias_regularizer=reg))

# %% [markdown]
# The rest of our setup is the same as it has been previously.

# %%
loss_fn = tf.keras.losses.BinaryCrossentropy()

network4.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])

# %%
history4 = network4.fit(X_xor, y_xor_one_hot, batch_size=2, epochs=100, verbose=0)

# %%
plt.plot(history4.history['accuracy'], label='Accuracy')
plt.plot(history4.history['mse'], label='MSE')
plt.ylim([-0.1, 1.1])
plt.legend()
plt.xlabel('Epoch');

# %% [markdown]
# This network trains *much* faster than the previous models.  While testing this notebook, the model frequently achieved zero loss by epoch 50.

# %%
plot_XOR_network(network4, two_outputs=True)
# Out:
# 458/458 [==============================] - 0s 202us/step

# %% [markdown]
# There are also more complex optimizers, such as the [Adam optimizer](https://arxiv.org/pdf/1412.6980.pdf) designed by Diederik Kingma and Jimmy Ba.  It uses a variety of techniques like adaptive learning rates and momentums to provide competitive performance.  To use it in Keras, call it as

# %%
opt = tf.keras.optimizers.Adam()

# %% [markdown]
# It has default parameters that empirically work well on a wide class of problems.

# %% [markdown]
# ## Complex Problems

# %% [markdown]
# [Neural Networks, Manifolds, and Topology](https://colah.github.io/posts/2014-03-NN-Manifolds-Topology/) by Christopher Olah has animated versions for $\tanh$ networks of some of the investigations and examples shown here.

# %% [markdown]
# Now let's consider a slightly more difficult problem for neural networks:

# %%
r1 = 0.5
r2 = np.sqrt(2*r1**2)
r3 = np.sqrt(r1**2 + r2**2)

fig = plt.figure()
ax = fig.add_subplot(111)

circle = plt.Circle((0, 0), r1)
annulus = matplotlib.patches.Wedge((0, 0), r3, 0, 360, width=r3-r2, color='r')
ax.add_artist(circle)
ax.add_artist(annulus)
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_aspect('equal', 'box');

# %% [markdown]
# By itself this is a relatively easy problem - if we convert to polar coordinates, we can just threshold based on the radius and have a very simple classifier that achieves 100% accuracy.  However, if we use the raw $x_1$ and $x_2$ inputs to a neural network, that information must be learned by the network.  The network must be able to construct a closed region in the plane, which requires more complexity than was necessary for XOR.
#
# For training a network we need specific inputs, so we will get 500 points from the circle and 500 from the annulus with their associated class labels:

# %%
X_circle = []
y_circle = []
for i in range(500):
    # Circle
    vec = np.random.uniform(-1, 1, 2)
    while np.linalg.norm(vec) > r1:
        vec = np.random.uniform(-1, 1, 2)
    X_circle.append(vec)
    y_circle.append(0)
        
    # Annulus
    vec = np.random.uniform(-1, 1, 2)
    while np.linalg.norm(vec) < r2 or np.linalg.norm(vec) > r3:
        vec = np.random.uniform(-1, 1, 2)
    X_circle.append(vec)
    y_circle.append(1)
    
X_circle = np.array(X_circle)
X_circle = X_circle.astype('float32')
y_circle = np.array(y_circle)
y_circle_one_hot = tf.keras.utils.to_categorical(y_circle, 2)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(X_circle[y_circle==0, 0], X_circle[y_circle==0, 1])
ax.scatter(X_circle[y_circle==1, 0], X_circle[y_circle==1, 1], c='r')
ax.set_xlim([-1, 1])
ax.set_ylim([-1, 1])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_aspect('equal', 'box');

# %% [markdown]
# Let's train a simple network on this and keep trying until we make sure we get a better solution than random:

# %%
accuracy_threshold = 0.79
hidden_width = 2
while True:
    network5 = tf.keras.Sequential()
    network5.add(tf.keras.layers.Dense(hidden_width, activation='relu'))
    network5.add(tf.keras.layers.Dense(2, activation='softmax'))

    loss_fn = tf.keras.losses.BinaryCrossentropy()
    opt = tf.keras.optimizers.Adam()
    network5.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])
    
    history5 = network5.fit(X_circle, y_circle_one_hot, batch_size=100, epochs=500, verbose=0)
    print('Trained one network to {} accuracy'.format(history5.history['accuracy'][-1]))
    if history5.history['accuracy'][-1] > accuracy_threshold :
        break
# Out:
# Trained one network to 0.7720000147819519 accuracy
# Trained one network to 0.800000011920929 accuracy

# %%
plt.plot(history5.history['accuracy'])
plt.ylim([-0.1, 1.1])
plt.xlabel('Epoch')
plt.ylabel('Accuracy');

# %%
plot_circles_network(network5, two_outputs=True)

# %% [markdown]
# Using this architecture it is possible to get accuracy of around 0.8 (and your network will likely look a little bit different from the one plotted above).

# %% [markdown]
# Now let's train a network that solves this, with three nodes in its hidden layer.  We may have to train it multiple times for it to find a solution with 100% accuracy.

# %%
hidden_width = 3
accuracy_threshold = 0.996
while True:
    network6 = tf.keras.Sequential()
    network6.add(tf.keras.layers.Dense(hidden_width, activation='relu'))
    network6.add(tf.keras.layers.Dense(2, activation='softmax'))

    loss_fn = tf.keras.losses.BinaryCrossentropy()
    opt = tf.keras.optimizers.Adam()
    network6.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])
    history6 = network6.fit(X_circle, y_circle_one_hot, batch_size=100, epochs=500, verbose=0)
    
    print('Trained one network to {} accuracy'.format(history6.history['accuracy'][-1]))
    if history6.history['accuracy'][-1] >= accuracy_threshold:
        break
# Out:
# Trained one network to 0.7910000085830688 accuracy
# Trained one network to 0.9819999933242798 accuracy
# Trained one network to 0.9819999933242798 accuracy
# Trained one network to 0.9850000143051147 accuracy
# Trained one network to 0.7770000100135803 accuracy
# Trained one network to 0.9980000257492065 accuracy

# %%
plt.plot(history6.history['accuracy'])
plt.ylim([-0.1, 1.1])
plt.xlabel('Epoch')
plt.ylabel('Accuracy');

# %%
plot_circles_network(network6, two_outputs=True)

# %% [markdown]
# ### Large Network
#
# We can also train a wider and deeper network on this problem to get a good solution nearly everytime.

# %%
network7 = tf.keras.Sequential()
network7.add(tf.keras.layers.Dense(8, activation='relu'))
network7.add(tf.keras.layers.Dense(8, activation='relu'))
network7.add(tf.keras.layers.Dense(8, activation='relu'))
network7.add(tf.keras.layers.Dense(2, activation='softmax'))

loss_fn = tf.keras.losses.BinaryCrossentropy()
opt = tf.keras.optimizers.Adam()
network7.compile(loss=loss_fn, optimizer=opt, metrics=['accuracy', 'mse'])
history7 = network7.fit(X_circle, y_circle_one_hot, batch_size=100, epochs=200, verbose=0)

# %%
plt.plot(history7.history['accuracy'])
plt.ylim([-0.1, 1.1])
plt.xlabel('Epoch')
plt.ylabel('Accuracy');

# %%
plot_circles_network(network7, two_outputs=True)

# %% [markdown]
# ## Comments
#
# 1. Some of the intuition from these small, two-input networks may not carry over in expected ways to higher dimensional problems.  Unfortunately, building intuition for those more complex problems is typically difficult due to the limited ability to analyze high dimensional networks.  We will discuss more complex problems in our next notebook.
# 2. Until relatively recently, one of the best methods for hyperparameter selection with neural networks was random search.  More sophisticated methods exist now, but without insight into the dataset it can be difficult to determine how to structure network architecture and training process
# 3. Keras used to be independent from the chosen backend, but its creator now works for Google (the makers of TensorFlow), and backends like PyTorch are no longer being updated, so the "recommended" backend is TensorFlow.  Keras is also being more closely tied into TensorFlow.
